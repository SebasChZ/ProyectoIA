# %%
import pandas as pd
import random
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, recall_score
from sklearn.preprocessing import StandardScaler

datasetDiabetes = pd.read_csv("./diabetes.csv")
datasetDiabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
datasetLeague = pd.read_csv("Challenger_Ranked_Games_15minute.csv")
datasetLeague
# Out:
#            gameId  blueWins  blueTotalGolds  blueCurrentGolds  blueTotalLevel  \
# 0      4247263043         0           24081              1190              44
# 1      4247155821         1           24162              2212              46
# 2      4243963257         0           22413              1563              41
# 3      4241678498         0           23837              3197              46
# 4      4241538868         1           27688              3663              44
# ...           ...       ...             ...               ...             ...
# 26829  4143231833         0           26110              1535              46
# 26830  4157911901         0           57503              3293              62
# 26831  3764171638         0           26091              2986              47
# 26832  4110201724         1           24734              4289              45
# 26833  4100240254         1           27507              5647              45
#
# ...

# %%
X = datasetDiabetes.drop(columns=["Outcome"])
y = datasetDiabetes["Outcome"]
trainingDataSetDiabetes, testingDataSetDiabetes, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
scaler = StandardScaler()
trainingDataSetDiabetes_scaled = scaler.fit_transform(trainingDataSetDiabetes)
testingDataSetDiabetes_scaled = scaler.transform(testingDataSetDiabetes)

# %%
# Inicializar el modelo de regresión logística
modelo_logistico = LogisticRegression()

# Ajustar el modelo al conjunto de entrenamiento
modelo_logistico.fit(trainingDataSetDiabetes_scaled, y_train)

# Predecir en el conjunto de prueba
y_pred = modelo_logistico.predict(testingDataSetDiabetes_scaled)

modelo_logistico = LogisticRegression()

# Evaluar el rendimiento del modelo
accuracy = accuracy_score(y_test, y_pred)
informe_clasificacion = classification_report(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# Imprimir resultados
print(f'Accuracy del modelo: {accuracy:.2f}')
print('\nInforme de clasificación:')
print(informe_clasificacion)
print(recall)
# Out:
# Accuracy del modelo: 0.81
#
# Informe de clasificación:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.87       105
#            1       0.75      0.61      0.67        49
#
#     accuracy                           0.81       154
#    macro avg       0.79      0.76      0.77       154
# weighted avg       0.81      0.81      0.81       154
#
# 0.6122448979591837

# %%
# Define the logistic regression model
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(trainingDataSetDiabetes.shape[1],)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Create a callback to track the loss values
class LossHistory(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        print(f"Epoch {epoch + 1}, Loss: {logs['loss']}, Accuracy: {logs['accuracy']}")

# Fit the model with the LossHistory callback
history_callback = LossHistory()
model.fit(trainingDataSetDiabetes_scaled, y_train, epochs=200, batch_size=32, callbacks=[history_callback])

# Evaluate the model
loss, accuracy = model.evaluate(testingDataSetDiabetes_scaled, y_test)
print(f'Accuracy del modelo: {accuracy:.2f}')

# Make predictions
y_pred = (model.predict(testingDataSetDiabetes_scaled) > 0.5).astype("int32")
informe_clasificacion = classification_report(y_test, y_pred)
print('\nInforme de clasificación:')
print(informe_clasificacion)
# Out:
# Epoch 1/200
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 7s 403ms/step - accuracy: 0.4688 - loss: 0.8061Epoch 1, Loss: 0.7586139440536499, Accuracy: 0.5846905708312988
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - accuracy: 0.5573 - loss: 0.7604
# Epoch 2/200
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7188 - loss: 0.5425Epoch 2, Loss: 0.7166427373886108, Accuracy: 0.5993485450744629
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step - accuracy: 0.6038 - loss: 0.7144
# Epoch 3/200
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6562 - loss: 0.6394Epoch 3, Loss: 0.7053840160369873, Accuracy: 0.6091205477714539
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - accuracy: 0.6104 - loss: 0.7192
# Epoch 4/200
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6562 - loss: 0.6745Epoch 4, Loss: 0.7213207483291626, Accuracy: 0.6156351566314697
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step - accuracy: 0.6343 - loss: 0.6796
# Epoch 5/200
# ...
