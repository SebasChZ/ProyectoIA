# %%
import pandas as pd
import random
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, recall_score
from sklearn.preprocessing import StandardScaler
# %run RegresionLogistica/RegresionLogistica.ipynb

datasetDiabetes = pd.read_csv("./diabetes.csv")
datasetDiabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#prepararDatos
X = datasetDiabetes.drop(columns=["Outcome"])
y = datasetDiabetes["Outcome"]
trainingDataSetDiabetes, testingDataSetDiabetes, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
modeloDiabetes = RegresionLogistica(trainingDataSetDiabetes, testingDataSetDiabetes, y_train, y_test)
modeloDiabetes.escalarDatos()
modeloDiabetes.calcular()
# Out:
# Accuracy del modelo: 0.79
#
# Informe de clasificación:
#               precision    recall  f1-score   support
#
#            0       0.77      0.93      0.84        92
#            1       0.86      0.58      0.69        62
#
#     accuracy                           0.79       154
#    macro avg       0.81      0.76      0.77       154
# weighted avg       0.80      0.79      0.78       154
#
# 0.5806451612903226

# %%
modeloDiabetes.calcularEpochs()
# Out:
# Epoch 1/200
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 7s 386ms/step - accuracy: 0.4062 - loss: 0.9533Epoch 1, Loss: 0.9161359667778015, Accuracy: 0.4527687430381775
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - accuracy: 0.4409 - loss: 0.8969
# Epoch 2/200
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3438 - loss: 0.8869Epoch 2, Loss: 0.8764562606811523, Accuracy: 0.46416938304901123
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - accuracy: 0.4606 - loss: 0.8799
# Epoch 3/200
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4375 - loss: 0.8285Epoch 3, Loss: 0.883023738861084, Accuracy: 0.47719869017601013
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.4660 - loss: 0.8883
# Epoch 4/200
#  1/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5000 - loss: 0.7454Epoch 4, Loss: 0.8476029634475708, Accuracy: 0.4918566644191742
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step - accuracy: 0.4958 - loss: 0.8469
# Epoch 5/200
# ...

# %%
#RegresionLineal para el 2do df

datasetLeague = pd.read_csv("Challenger_Ranked_Games_15minute.csv")

# %%
#remove columnas que dups o que no afectan directamente
X_League = datasetLeague.drop(columns=["gameId", "blueFirstTowerLane", "blueDragnoType", "redFirstTowerLane", "redDragnoType", "redWins"])
y_League = datasetLeague["blueWins"] # 1 gana blue
trainingDataSetLeague, testingDataSetLeague, y_trainLeague, y_testLeague = train_test_split(X_League, y_League, test_size=0.2)

# %%
modeloLeague = RegresionLogistica(trainingDataSetLeague, testingDataSetLeague, y_trainLeague, y_testLeague)

# %%
modeloLeague.escalarDatos()

# %%
modeloLeague.calcular()
# Out:
# Accuracy del modelo: 1.00
#
# Informe de clasificación:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2673
#            1       1.00      1.00      1.00      2694
#
#     accuracy                           1.00      5367
#    macro avg       1.00      1.00      1.00      5367
# weighted avg       1.00      1.00      1.00      5367
#
# 1.0

# %%
modeloLeague.calcularEpochs()
# Out:
# Epoch 1/200
# 617/671 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - accuracy: 0.5697 - loss: 0.6934Epoch 1, Loss: 0.5278870463371277, Accuracy: 0.7175199389457703
# 671/671 ━━━━━━━━━━━━━━━━━━━━ 1s 497us/step - accuracy: 0.5814 - loss: 0.6803
# Epoch 2/200
# 622/671 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - accuracy: 0.8724 - loss: 0.3371Epoch 2, Loss: 0.3014025092124939, Accuracy: 0.8966320157051086
# 671/671 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - accuracy: 0.8741 - loss: 0.3347
# Epoch 3/200
# 601/671 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - accuracy: 0.9439 - loss: 0.2241Epoch 3, Loss: 0.20239612460136414, Accuracy: 0.9557926058769226
# 671/671 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - accuracy: 0.9450 - loss: 0.2219
# Epoch 4/200
# 603/671 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - accuracy: 0.9783 - loss: 0.1553Epoch 4, Loss: 0.1392054706811905, Accuracy: 0.9837424755096436
# 671/671 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - accuracy: 0.9788 - loss: 0.1537
# Epoch 5/200
# ...
